# %%
#from ipynb.fs.full.LocationCleaningScript import clean_location
from ipynb.fs.full.cleanIndustries import cleanIndustries
# from ipynb.fs.full.CurrencyConverter import *
#from ipynb.fs.full.NormalizeWorkExperience import NormalizeExperience
import pandas as pd
import urllib.request
import json
from datascience import *
import numpy as np
import re
import math
def RemoveSpacesFromTitles(df):
    
    df.columns = [c.replace(' ', '_') for c in df.columns]
    return df
def NormalizeExperience(filename):
    df = pd.read_csv(filename)
    df = df.replace(to_replace = ['5-7 years'], value = '5 - 7 years')
    df = df.replace(to_replace = ['1 year or less'], value = '0 - 1 years')
    return df
  

#x = x.to_df()

# %%
class currencyConverter:
    rates = {}
    def __init__(self, url):
        data = urllib.request.urlopen(url).read().decode('utf-8')
        f = json.loads(data)
        self.rates = f["rates"]
        
        
    def convert(self, amount, f, t):
        output = 0
        if f != 'USD':
            output = amount / self.rates[f] * self.rates['USD']
            return output
        return amount
        
def convertCurrency(df):
    for i in range(len(df['Currency'])):
        df["Annual_Salary"][i]= str(    df["Annual_Salary"][i] )
        df["Annual_Salary"][i]= ''.join(i for i in df["Annual_Salary"][i] if i.isdigit())
        if df["Currency"][i] == "Other" or df["Annual_Salary"][i] == "":
            df["Annual_Salary"][i] = 0
        else:
            df["Annual_Salary"][i]=float(    df["Annual_Salary"][i] )
        
       

        
        if df["Currency"][i] in c.rates and df["Currency"][i] != "USD" :
            df['Annual_Salary'][i] =c.convert(float(df['Annual_Salary'][i]), df["Currency"][i], 'USD')

    return df

c = currencyConverter("http://data.fixer.io/api/latest?access_key=238f1925907e0f01a7fa1dc2b4042967")

# %%
def clean2019locs(tbl):
    data = list(tbl["Location"])
    for i in range(len(data)):
        data[i] = str(data[i])
        data[i] = data[i].strip()
        chars = ["'",'"',',','.','/',"-",'—']
        if '(' in data[i]:
            data[i] =data[i][:data[i].find("(")]
        for c in range(len(chars)):
            if chars[c] in data[i]:
                data[i] = data[i].replace(chars[c]," ")
    tbl["Location"] = data
    return tbl

# %%
table = NormalizeExperience('../Data/2019_Results.csv')
table = RemoveSpacesFromTitles(table)
table = cleanIndustries(table)
table = convertCurrency(table)
table = clean2019locs(table)
table = Table.from_df(table)
table = table.remove(table.where("Annual_Salary",are.above(10000000)))
table.where("Annual_Salary",are.above(10000000))
#print(np.unique(table["Currency"]))
#table.to_csv("CleanedData2019.csv")
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Age</th> <th>Industry</th> <th>Job_Title</th> <th>Annual_Salary</th> <th>Currency</th> <th>Location</th> <th>Work_Experience</th> <th>Context_for_Job</th> <th>Other</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>45-54     </td> <td>Property or Construction            </td> <td>Property Manager                                            </td> <td>1.39e+07     </td> <td>USD     </td> <td>Washington  DC                              </td> <td>21 - 30 years   </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Health care                         </td> <td>Veterinary technician                                       </td> <td>1.85336e+08  </td> <td>USD     </td> <td>Pittsburgh  Pa  USA                         </td> <td>11 - 20 years   </td> <td>Specialty medicine within a referral hospital               </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>55-64     </td> <td>Education                           </td> <td>Associate Professor of Management and Leadership            </td> <td>1.681e+07    </td> <td>USD     </td> <td>Fort Worth  TX  USA                         </td> <td>21 - 30 years   </td> <td>Mid-sized private university                                </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>45-54     </td> <td>Other                               </td> <td>Director of Account Based Marketing                         </td> <td>1.35e+07     </td> <td>USD     </td> <td>Providence  RI  USA                         </td> <td>21 - 30 years   </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>25-34     </td> <td>Law or Law Enforcement              </td> <td>Associate Attorney                                          </td> <td>2e+08        </td> <td>USD     </td> <td>Los Angeles County                          </td> <td>5 - 7 years     </td> <td>Practicing 6 years                                          </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>25-34     </td> <td>Computing or Tech                   </td> <td>Associate Director Records Information Management           </td> <td>1.5e+07      </td> <td>USD     </td> <td>Boston MA                                   </td> <td>5 - 7 years     </td> <td>I manage Trial Master Files, Systems, the Archives...       </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Health care                         </td> <td>Manager                                                     </td> <td>9.00002e+09  </td> <td>USD     </td> <td>Bridgewater  nj  usa                        </td> <td>11 - 20 years   </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Property or Construction            </td> <td>Clerk I                                                     </td> <td>7.40004e+09  </td> <td>USD     </td> <td>Anchorage  Alaska  USA                      </td> <td>11 - 20 years   </td> <td>Administrative Assistant                                    </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Research                            </td> <td>Associate Professor/Department Chair                        </td> <td>7.10006e+08  </td> <td>USD     </td> <td>Midwest  USA                                </td> <td>11 - 20 years   </td> <td>I am in the humanities, which has significantly lower sa ...</td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>25-34     </td> <td>Publishing                          </td> <td>Managing Director                                           </td> <td>4.76118e+09  </td> <td>EUR     </td> <td>Bolzano Province of Bolzano Italy           </td> <td>8 - 10 years    </td> <td>Job title context: very small company/agency (3 employee ...</td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Other                               </td> <td>Project accountant                                          </td> <td>5.60003e+08  </td> <td>USD     </td> <td>San Francisco  California                   </td> <td>8 - 10 years    </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>25-34     </td> <td>Education                           </td> <td>Fellow                                                      </td> <td>2.38058e+09  </td> <td>EUR     </td> <td>Dresden Germany                             </td> <td>2 - 4 years     </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Health care                         </td> <td>Sr. Director of Finance/Corporate Controller                </td> <td>1.95e+07     </td> <td>USD     </td> <td>San Diego  CA                               </td> <td>8 - 10 years    </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Other                               </td> <td>Producer                                                    </td> <td>9.69576e+09  </td> <td>CAD     </td> <td>nan                                         </td> <td>11 - 20 years   </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>25-34     </td> <td>Computing or Tech                   </td> <td>Customer Service Representative                             </td> <td>3.70002e+08  </td> <td>USD     </td> <td>Houston  TX  USA                            </td> <td>5 - 7 years     </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Publishing                          </td> <td>Literary Agent                                              </td> <td>5.05008e+09  </td> <td>USD     </td> <td>New York City                               </td> <td>11 - 20 years   </td> <td>nan                                                         </td> <td>I work for base salary plus commission/bonuses hence the ...</td>
#         </tr>
#         <tr>
#             <td>35-44     </td> <td>Health care                         </td> <td>Senior Principal Biostatistician                            </td> <td>1.613e+09    </td> <td>USD     </td> <td>Outside of Philadelphia  PA  USA            </td> <td>11 - 20 years   </td> <td>nan                                                         </td> <td>nan                                                         </td>
#         </tr>
#         <tr>
#             <td>45-54     </td> <td>Publishing                          </td> <td>Content Licensing Coordinator                               </td> <td>4.90004e+09  </td> <td>USD     </td> <td>Columbus  OH  USA                           </td> <td>21 - 30 years   </td> <td>License images/
