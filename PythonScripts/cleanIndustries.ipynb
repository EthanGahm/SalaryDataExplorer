# %%
import pandas as pd
import re


def cleanIndustries(data):
    # Standardizes the Industries options
    data.loc[data["Industry"].isnull(),'Industry'] = 'NULL'
    data.loc[data['Industry'].str.contains('politic', flags=re.I, regex=True), 'Industry'] = 'Government and Public Administration'
    data.loc[data['Industry'].str.contains('restau', flags=re.I, regex=True), 'Industry'] = 'Food'
    data.loc[data['Industry'].str.contains('archae', flags=re.I, regex=True), 'Industry'] = 'Research'
    data.loc[data['Industry'].str.contains('arts', flags=re.I, regex=True), 'Industry'] = 'Art & Design'
    data.loc[data['Industry'].str.contains('science', flags=re.I, regex=True), 'Industry'] = 'Research'
    data.loc[data['Industry'].str.contains('museum', flags=re.I, regex=True), 'Industry'] = 'Leisure, Sport & Tourism'
    data.loc[data['Industry'].str.contains('telecom', flags=re.I, regex=True), 'Industry'] = 'Utilities & Telecommunications'
    data.loc[data['Industry'].str.contains('auto', flags=re.I, regex=True), 'Industry'] = 'Auto Repair'
    data.loc[data['Industry'].str.contains('consul', flags=re.I, regex=True), 'Industry'] = 'Business or Consulting'
    data.loc[data['Industry'].str.contains('medical', flags=re.I, regex=True), 'Industry'] = 'Health care'
    data.loc[data['Industry'].str.contains('environ', flags=re.I, regex=True), 'Industry'] = 'Environment'
    data.loc[data['Industry'].str.contains('vet', flags=re.I, regex=True), 'Industry'] = 'Health care'
    data.loc[data['Industry'].str.contains('telecom', flags=re.I, regex=True), 'Industry'] = 'Utilities & Telecommunications'
    data.loc[data['Industry'].str.contains('transport|logistics', flags=re.I, regex=True), 'Industry'] = 'Transport or Logistics'
    data.loc[data['Industry'].str.contains('energy', flags=re.I, regex=True), 'Industry'] = 'Energy'
    data.loc[data['Industry'].str.contains('sale', flags=re.I, regex=True), 'Industry'] = 'Sales'
    data.loc[data['Industry'].str.contains('retail', flags=re.I, regex=True), 'Industry'] = 'Retail'
    data.loc[data['Industry'].str.contains('prop|construction', flags=re.I, regex=True), 'Industry'] = 'Property or Construction'
    data.loc[data['Industry'].str.contains('nonprofit|non-profit|non profit', flags=re.I, regex=True), 'Industry'] = 'Nonprofits'
    data.loc[data['Industry'].str.contains('digital', flags=re.I, regex=True), 'Industry'] = 'Media & Digital'
    data.loc[data['Industry'].str.contains('market', flags=re.I, regex=True), 'Industry'] = 'Marketing, Advertising & PR'
    data.loc[data['Industry'].str.contains('tour', flags=re.I, regex=True), 'Industry'] = 'Leisure, Sport & Tourism'
    data.loc[data['Industry'].str.contains('law', flags=re.I, regex=True), 'Industry'] = 'Law or Law Enforcement'
    data.loc[data['Industry'].str.contains('insurance', flags=re.I, regex=True), 'Industry'] = 'Insurance'
    data.loc[data['Industry'].str.contains('hospitality|events', flags=re.I, regex=True), 'Industry'] = 'Hospitality & Events'
    data.loc[data['Industry'].str.contains('librar', flags=re.I, regex=True), 'Industry'] = 'Library'
    data.loc[data['Industry'].str.contains('health', flags=re.I, regex=True), 'Industry'] = 'Health care'
    data.loc[data['Industry'].str.contains('government', flags=re.I, regex=True), 'Industry'] = 'Government and Public Administration'
    data.loc[data['Industry'].str.contains('entertainment', flags=re.I, regex=True), 'Industry'] = 'Entertainment'
    data.loc[data['Industry'].str.contains('education', flags=re.I, regex=True), 'Industry'] = 'Education'
    data.loc[data['Industry'].str.contains('computing|tech', flags=re.I, regex=True), 'Industry'] = 'Computing or Tech'
    data.loc[data['Industry'].str.contains('business', flags=re.I, regex=True), 'Industry'] = 'Business or Consulting'
    data.loc[data['Industry'].str.contains('design', flags=re.I, regex=True), 'Industry'] = 'Art & Design'
    data.loc[data['Industry'].str.contains('agriculture', flags=re.I, regex=True), 'Industry'] = 'Agriculture or Forestry'
    data.loc[data['Industry'].str.contains('accounting', flags=re.I, regex=True), 'Industry'] = 'Accounting, Banking & Finance'
    data.loc[data['Industry'].str.contains('engineering|manufacturing', flags=re.I, regex=True), 'Industry'] = 'Engineering or Manufacturing'
    data.loc[data['Industry'].str.contains('food', flags=re.I, regex=True), 'Industry'] = 'Food'
    data.loc[data['Industry'].str.contains('public health', flags=re.I, regex=True), 'Industry'] = 'Health care'
    data.loc[data['Industry'].str.contains('software', flags=re.I, regex=True), 'Industry'] = 'Computing or Tech'
    data.loc[data['Industry'].str.contains('libraries', flags=re.I, regex=True), 'Industry'] = 'Library'
    data.loc[data['Industry'].str.contains('aero', flags=re.I, regex=True), 'Industry'] = 'Aerospace'
    data.loc[data['Industry'].str.contains('game|gaming', flags=re.I, regex=True), 'Industry'] = 'Computing or Tech'
    data.loc[data['Industry'].str.contains('research', flags=re.I, regex=True), 'Industry'] = 'Research'
    data.loc[data['Industry'].str.contains('academ', flags=re.I, regex=True), 'Industry'] = 'Research'
    data.loc[data['Industry'].str.contains('publish', flags=re.I, regex=True), 'Industry'] = 'Publishing'
    data.loc[data['Industry'].str.contains('real estate', flags=re.I, regex=True), 'Industry'] = 'Property or Construction'
    data.loc[data['Industry'].str.contains('pharma', flags=re.I, regex=True), 'Industry'] = 'Health care'

    # The options that will be shown in the dropdown
    industries = ['Accounting, Banking & Finance', 'Agriculture or Forestry','Art & Design','Business or Consulting',
              'Computing or Tech','Education','Engineering or Manufacturing', 'Entertainment', 'Government and Public Administration', 
              'Health care','Hospitality & Events', 'Insurance', 'Law or Law Enforcement','Leisure, Sport & Tourism', 'Marketing, Advertising & PR',
             'Media & Digital', 'Nonprofits', 'Property or Construction', 'Recruitment or HR', 'Retail', 'Sales', 'Social Work',
             'Transport or Logistics', 'Utilities & Telecommunications','Publishing','Research','Aerospace','Library','Food','Energy','Environment', 'Auto Repair']

    # The remaining options set to 'Other'
    data.loc[~data['Industry'].isin(industries), 'Industry'] = 'Other'

    return data
