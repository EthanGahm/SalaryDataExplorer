# %%
import pandas as pd
import urllib.request
import json

class currencyConverter:
    rates = {}
    def __init__(self, url):
        data = urllib.request.urlopen(url).read().decode('utf-8')
        f = json.loads(data)
        self.rates = f["rates"]
        
        
    def convert(self, amount, f, t):
        output = 0
        if f != 'USD':
            output = amount / self.rates[f] * self.rates[t]
            return output
        return amount
        
def convertCurrency(df):
    df = pd.read_csv(df)
    for i in range(len(df['Currency'])):
        f = df['Currency'][i]
        salary = df['Annual Salary'][i].replace(',', '')
        otherComp = df['Other Compensation'][i]
        if not pd.isna(df['Other Compensation'][i]):
            salary = float(salary) + float(otherComp)
        if f == 'Other':
            otherCur = df['Other'][i]
            if otherCur == 'Peso Argentino' or otherCur == 'Argentinian peso (ARS)' or otherCur == 'Argentine Peso':
                otherCur = 'ARS'
            if otherCur == 'Indian rupees' or otherCur == 'INR (Indian Rupee)':
                otherCur = 'INR'
            if otherCur == 'BRL (R$)' or otherCur == 'BR$':
                otherCur = 'BRL'
            if otherCur == 'Dkk' or otherCur == 'Danish Kroner' or otherCur == 'dkk':
                otherCur = 'DKK'
            if otherCur == 'Mexican pesos' or otherCur == 'Mexican Pesos':
                otherCur = 'MXN'
            if otherCur == 'Bdt':
                otherCur = 'BDT'
            if otherCur == 'American Dollars':
                otherCur = 'USD'
            if otherCur == 'Php' or otherCur == 'Philippine Peso' or otherCur == 'Philippine peso (PHP)' or otherCur == 'PhP (Philippine Peso)' or otherCur == 'Philippine Pesos':
                otherCur = 'PHP'
            if otherCur == 'PLN (Polish zloty)' or otherCur == 'Polish Złoty':
                otherCur = 'PLN'
            if otherCur == 'czech crowns' or otherCur == 'Czk':
                otherCur = 'CZK'
            if otherCur == 'Norwegian kroner (NOK)' or otherCur == 'Nok':
                otherCur = 'NOK'
            if otherCur == 'ILS/NIS' or otherCur == 'NIS (new Israeli shekel)' or otherCur == 'ILS (Shekel)' or otherCur == 'Israeli Shekels' or otherCur == 'Ils':
                otherCur = 'ILS'
            if otherCur == 'US Dollar':
                otherCur = 'USD'
            if otherCur == 'RMB (chinese yuan)' or otherCur == 'China RMB' or otherCur == 'RM':
                otherCur = 'CNY'
            if otherCur == 'Taiwanese dollars' or otherCur == 'NTD':
                otherCur = 'TWD'
            if otherCur == 'KRW (Korean Won)' or otherCur == 'Korean Won ':
                otherCur = 'KRW'
            if otherCur == 'Sgd':
                otherCur = 'SGD'
            if otherCur == 'AUD Australian' or otherCur == 'Australian Dollars ':
                otherCur = 'AUD'
            if otherCur == 'Euro':
                otherCur = 'EUR'
            if otherCur == 'THAI  BAHT':
                otherCur = 'THB'
            if otherCur == 'IDR ':
                otherCur = 'IDR'
            if otherCur in c.rates:
                df['Annual Salary'][i] = "{:.2f}".format(c.convert(float(salary), otherCur, 'USD'))
        else:
            if f == 'AUD/NZD':
                f = 'AUD'
            df['Annual Salary'][i] = "{:.2f}".format(c.convert(float(salary), f, 'USD'))
    return df

c = currencyConverter("http://data.fixer.io/api/latest?access_key=238f1925907e0f01a7fa1dc2b4042967")
# print(c.convert(5, 'EUR', 'USD'))
convertCurrency("../2021_Results.csv")
# print(c.rates)
# Out:
# <ipython-input-5-1f828add5923>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Annual Salary'][i] = "{:.2f}".format(c.convert(float(salary), f, 'USD'))
# <ipython-input-5-1f828add5923>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Annual Salary'][i] = "{:.2f}".format(c.convert(float(salary), otherCur, 'USD'))
#                 Timestamp    Age                       Industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 26334  5/25/2021 10:39:03  45-54              Computing or Tech
# 26335  5/25/2021 10:47:06  45-54                    Health care
# 26336  5/25/2021 10:50:28  25-34              Computing or Tech
# 26337  5/25/2021 10:55:57  25-34         Business or Consulting
# 26338  5/25/2021 12:04:23  25-34                    Health care
#
#                                       Job Title Annual Salary Currency  \
# 0            Research and Instruction Librarian      55000.00      USD
# 1      Change & Internal Communications Manager      82996.94      GBP
# 2                          Marketing Specialist      34000.00      USD
# 3                               Program Manager      65000.00      USD
# 4                            Accounting Manager      67000.00      USD
# ...                                         ...           ...      ...
# 26334       Information Technology Professional      76480.00      USD
# 26335                            System Analyst      75000.00      USD
# 26336                Database Software Engineer      93000.00      USD
# 26337                          Senior Associate     161000.00      USD
# 26338                       Director, Analytics     160000.00      USD
#
#       Work Experience Context for Job Other  Other Compensation Context  \
# 0           5-7 years             NaN   NaN                 0.0     NaN
# 1        8 - 10 years             NaN   NaN              4000.0     NaN
# 2         2 - 4 years             NaN   NaN                 NaN     NaN
# 3        8 - 10 years             NaN   NaN              3000.0     NaN
# 4        8 - 10 years             NaN   NaN              7000.0     NaN
# ...               ...             ...   ...                 ...     ...
# 26334   31 - 40 years             NaN   NaN                 NaN     NaN
# 26335   11 - 20 years             NaN   NaN                 0.0     NaN
# 26336   11 - 20 years             NaN   NaN                 NaN     NaN
# 26337    8 - 10 years             NaN   NaN             10000.0     NaN
# 26338   11 - 20 years             NaN   NaN             25000.0     NaN
#
#               Country           State         City Highest Level of Education  \
# 0       United States   Massachusetts       Boston            Master's degree
# 1      United Kingdom             NaN    Cambridge             College degree
# 2                  US       Tennessee  Chattanooga             College degree
# 3                 USA       Wisconsin    Milwaukee             College degree
# 4                  US  South Carolina   Greenville             College degree
# ...               ...             ...          ...                        ...
# 26334             USA       Minnesota  Minneapolis             College degree
# 26335   United States           Texas       Austin            Master's degree
# 26336   United States          Oregon     Portland            Master's degree
# 26337   United States        New York     New York            Master's degree
# 26338             USA        New York          NYC             College degree
#
#            Gender                     Race
# 0           Woman                    White
# 1      Non-binary                    White
# 2           Woman                    White
# 3           Woman                    White
# 4           Woman                    White
# ...           ...                      ...
# 26334       Woman                    White
# 26335       Woman                    White
# 26336       Woman                    White
# 26337         Man  Asian or Asian American
# 26338  Non-binary                    White
#
# [26339 rows x 17 columns]
