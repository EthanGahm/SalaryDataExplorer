# %%
import pandas as pd
def RemoveUnnamedColumn(filename):
    df = pd.read_csv('../Data/' + filename)
    df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
    df.to_csv("../Data/FinalData2021.csv", index=False)
RemoveUnnamedColumn('FinalData2021_Fixed_Weird_Rows.csv')

# %%
# Out:
#              Timestamp    Age                       Industry  \
# 0      4/27/2021 11:02  25-34                      Education
# 1      4/27/2021 11:02  25-34              Computing or Tech
# 2      4/27/2021 11:02  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02  25-34                     Nonprofits
# 4      4/27/2021 11:02  25-34  Accounting, Banking & Finance
# ...                ...    ...                            ...
# 26331  5/25/2021 10:39  45-54              Computing or Tech
# 26332  5/25/2021 10:47  45-54                    Health care
# 26333  5/25/2021 10:50  25-34              Computing or Tech
# 26334  5/25/2021 10:55  25-34         Business or Consulting
# 26335  5/25/2021 12:04  25-34                    Health care
#
#                                       Job_Title Annual_Salary Currency  \
# 0            Research and Instruction Librarian         55000      USD
# 1      Change & Internal Communications Manager      80912.35      GBP
# ...
