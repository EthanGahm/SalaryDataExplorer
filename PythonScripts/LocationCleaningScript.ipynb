# %%
import numpy as np
import math
import pandas as pd
from datascience import *
import country_converter as cc
from autocorrect import Speller as sp
from array import *
from geotext import GeoText
from spellchecker import SpellChecker
import re
tbl = pd.read_csv('../Data/FinalData2021.csv')
countries = list(tbl["Country"])
st = list(tbl["State"])
cities = list(tbl["City"])
spell = sp(lang='en')
s = SpellChecker()
#tbl
table_copy = tbl

# %%
def standardize_countries(table):
    
    usa_vars = make_array( 'For The United States Government, But Posted Overseas', 'Usa','Us', 'US','Hartford','California','America','San Francisco','The United States','U S', 'UNITED STATES', 'USA',
           'USA (company is based in a Up territory, I work remote)',
           'USA tomorrow', "USA, but for foreign gov't", 'USA-- Virgin Islands','Unite States',
           'United  States','United State',
           'United State of America', 'United States',
           'United States (I work from home and my clients are all over the Up/Canada/X',
           'United States Of America', 'United States of America',
           'United States of American', 'United States of Americas',
           'United States of america', 'United States- Puerto Rico',
           'United Statues', 'United Status','United state', 'United states', 'United states of America',
           'United states of america', 'United y', 'UnitedStates', 'Us', 'Usa', 'Use','Virginia','america','united States', 'united stated', 'united states', 'united states of america','us', 'usa', '🇺🇸', 'United State Of America'
, 'United States (I Work From Home And My Clients Are All Over The Up/Canada/Px','Ux','United Stated','United States (I Work From Home And My Clients Are All Over The Up/Canada/X',
 'United States Of American', 'United States Of Americas',
 'United States of America', 'United Y', 'Unitedstates','Up Of A','Usa (Company Is Based In A Up Territory, I Work Remote)' ,'Usa Tomorrow'
, "Usa, But For Foreign Gov'T" ,'Usa-- Virgin Islands' )
    netherlands_vars = make_array('Netherlands','The Netherlands',  'The netherlands', 'netherlands','the Netherlands','the netherlands','Nederland')
    not_specified = make_array('Race','White','Sa' ,'Remote',"We Don'T Get Raises, We Get Quarterly Bonuses, But They Periodically Passes Income In The Area You Work, So I Got A Raise Because A 3Rd Party Assessment Showed I Was Paid Too Little For The Area We Were Located"
 ,'Worldwide (Based In Up But Short Term Trips Around The World)','Ss','Sd','Remote (Philippines)' ,  'N/A (Remote From Wherever I Want)' ,'Currently Finance', 'Canada And Usa','I Was Brought In On This Salary To Help With The Hr And Very Quickly Was Promoted To Current Position But Compensation Was Not Altered',"I Earn Commission On Sales If I Meet Quota, I'M Guaranteed Another 16K Min Last Year I Earned An Additional 27K It'S Not Uncommon For People In My Space To Earn 100K+ After Commission",'Bonus Based On Meeting Yearly Goals Set W/ My Supervisor','I Work For A A-Based Organization, Though I Am Personally In The Up','Not specified/unclear response', 'Canada and usa','International',   'For the United States government, but posted overseas','From New Zealand but on projects across A', 'Worldwide (based in Up but short term trips around the world)','X', 'Y', 'Z', 'n/a (remote from wherever I want)', "I earn commission on sales If I meet quota, I'm guaranteed another 16k min Last year i earned an additional 27k It's not uncommon for people in my space to earn 100k+ after commission",
           'I was brought in on this salary to help with the He and very quickly was promoted to current position but compensation was not altered','S','A', "We don't get raises, we get quarterly bonuses, but they periodically passes income in the area you work, so I got a raise because a 3rd party assessment showed I was paid too little for the area we were locate", 'bonus based on meeting yearly goals set w/ my supervisor','$2,17584/year is deducted for benefits','Contracts','Global','E',   'Currently finance', 'europe','Remote (philippines)','$2,17584/Year Is Deducted For Benefits', 'Ae')
    uk_only = make_array( 'I Work For A Ae-Based Organization, Though I Am Personally In The Up', "I Work For An Up Based Company But I'M From Argentina",'From Romania, But For An Up Based Company', 'Austria, But I Work Remotely For A Dutch/British Company','I Am Located In Canada But I Work For A Company In The Up', 'Uk', 'United Kingdom', 'United kingdom','united kingdom', 'uk', 'up','Up for Up company','The Up', 'Up govt employee overseas, country withheld',
           'Up, but for globally fully remote company', 'Up, remote', 'Up>','Up','Up (Northern England)', 'Up For Up Company'
 ,'Up Govt Employee Overseas, Country Withheld',
 'Up, But For Globally Fully Remote Company', 'Up, Remote')
    england = make_array( 'England', 'England, Gb', 'England, United Kingdom', 'England, Up', 'England/Up','United Kingdom (England)', 'Up (England)', 'Up (northern England)', 'england','Up of A',)
    wales =make_array( 'Wales',
           'Wales (united kingdom)', 'Wales (up)', 'Wales, up', 'Wales (United Kingdom)' ,'Wales (Up)' ,'Wales, Up')
    n_ireland = make_array('Northern ireland',
             'Northern ireland, united kingdom','Up (Northern Ireland)','Northern Ireland, United Kingdom')
    nz=make_array('Aotearoa New Zealand', 'New Zealand',
           'New Zealand Aotearoa','From New Zealand But On Projects Across Apa')
    canada = make_array('Can', 'Canada',
           'Canada, Ottawa, Ontario',)

    spell = sp(lang="en")
    for country in range(len(countries)):
        countries[country] = str(countries[country])
        countries[country] = countries[country].replace(".","").strip()
        countries[country] = spell(countries[country])
        countries[country] = countries[country].title()
        if countries[country] == 'Trinidad And Tobacco':
            countries[country] = "Trinidad and Tobago"

        if countries[country] == 'Mainland China':
            countries[country] = "China"
        if countries[country] == 'Japan, Up Gov Position':
            countries[country] = "Japan"
        if countries[country] == 'Scotland, Up':
            countries[country] = "Scotland"
        if countries[country] == 'Australian':
            countries[country] = "Australia"
        if countries[country] ==  'Luxemburg':
            countries[country] = 'Luxembourg'
        if countries[country] ==  'The Bananas':
            countries[country] = 'The Bahamas'
        if countries[country] ==  'Paramá':
            countries[country] = 'Panama'
        if countries[country] ==  'Is':
            countries[country] = 'Iceland'
        if countries[country] ==  'Brasil':
            countries[country] = 'Brazil'
        if countries[country] ==  'México':
            countries[country] = 'Mexico'
        if countries[country] ==   "Cote D'Voice":
            countries[country] = 'Ivory Coast'
        if countries[country] ==  'In':
            countries[country] = 'India'
        if countries[country] ==  'Danmark':
            countries[country] = 'Denmark'
        if countries[country] ==  'Jersey, Channel Islands':
            countries[country] = 'Jersey'
        if countries[country] ==   'Argentina Ut M Rg In In Thailand':
            countries[country] = 'Thailand'
        if countries[country] ==   'Argentina Ut M R In In Thailand':
            countries[country] = 'Thailand'
        if countries[country] ==  'Italy (South)':
            countries[country] = 'Italy'
        if countries[country] in usa_vars:
            countries[country] = "United States of America"
        if countries[country] in netherlands_vars:
            countries[country] = "Netherlands"
        if countries[country] in uk_only:
            countries[country] = "United Kingdom"
        if countries[country] == 'Us':
            countries[country] = "United States of America"
        if countries[country] in england:
            countries[country] = "England"
        if countries[country] in wales:
            countries[country] = "Wales"
        if countries[country] in canada:
            countries[country] = "Canada"
        if countries[country] in n_ireland:
            countries[country] = "Northern Ireland"
        if countries[country] in nz:
            countries[country] = "New Zealand"
        if countries[country] in not_specified:
            countries[country] = ""



    
    for i in range(len(countries)):

        if countries[i] == "United Kingdom" and st[i] != "nan" :

            countries.pop(i)
            countries.insert(i,"United States of America")  


    table["Country"] = countries
    
    
    
    return table

# %%
def standardize_states(table):

    spell = sp(lang='en')
    for s in range(len(st)):
        st[s] = str(st[s])
        st[s] = st[s].replace(".","").strip()
        st[s]= spell(st[s])
        st[s] = st[s].title()
        if "," in st[s]:
            st.pop(s)
            st.insert(s,"")
        if st[s] == "Nan":
            st.pop(s)
            st.insert(s,"")

   # unique_states = np.unique(st)
    table["State"] = st
    
    return table

# %%
## this method checks if a certain string contains no alphanumeric characters.
def no_alphanumeric(str):
    l = len(str)
    count =0
    for letter in str:
        if not letter.isalnum():
            count = count +1
    if l == count:
        return True
    else:
        return False
## this method checks if a certain string contains only number characters.
def only_numbers(str):
    l = len(str)
    count =0
    for letter in str:
        if  letter.isdecimal():
            count = count +1
    if l == count:
        return True
    else:
        return False

# %%
def standardize_cities(table):
    count =0
    count2 =0 
    misspelled = s.unknown(str(cities))
    commas = []
    for c in range(len(cities)):
       # print(cities[c])
        cities[c] = str(cities[c]).title()
        cities[c] = cities[c].replace(".","").strip()
        if len(cities[c]) >= 25:
            cities[c] = ""
        if no_alphanumeric(cities[c]):
            cities[c] = ""
        if only_numbers(cities[c]):
            cities[c] = ""
        if "indenti" in cities[c]:
            cities[c] = ""
        if "Indenti" in cities[c]:
            cities[c] = ""
        if "(" in cities[c]:
           #commas.append(cities[c])
            #print(cities[c])
            #print('---------')
            x = cities[c].find("(")
            cities[c] = cities[c][:x]
            #print(cities[c])
        if cities[c] == 'Washington, DC':
            cities[c] = "Washington DC"
        if "," in cities[c]:
            x2 = cities[c].find(",")
            cities[c] = cities[c][:x2]
        if "prefer" in cities[c]:
           # print(cities[c])
            cities[c] = ""  
        if "Prefer" in cities[c]:
           # print(cities[c])
            cities[c] = ""
        if "remote" in cities[c]:
           # print(cities[c])
            cities[c] = ""
        if "Remote" in cities[c]:
           # print(cities[c])
            cities[c] = ""
            commas.append(cities[c])
        if cities[c] == 'Barxelona':
            cities[c] = 'Barcelona'
            
            
            
            count = count+1
        if cities[c] in ['Virgina Beach',
'Virgnia Beach',]:
            cities[c] = "Virginia Beach"
            count = count+1
#             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Virginia Beach"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Virginia Beach"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Alexandria VA',
'Alexandrira','Alexandria Va']:
            cities[c] = 'Alexandria'
            count = count+1
            #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Alexandria"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Alexandria"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Atlanta Metro',
'Atlanta Metro Area',
'Atlanta Suburb',
'AtlantA',]:
            cities[c] = 'Atlanta'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Atlanta"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Atlanta"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Baltimore Area',
'Baltimore County',
'Baltimore Metro',
'Baltimore Suburb',
'Baltimore Suburbs',]:
            cities[c] = 'Baltimore'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Baltimore"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Baltimore"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Boston Area',
'Boston Ma',
'Boston Massachusetts',
'Boston Metro',
'Boston Metro Area',
'Boston Suburb',
'Boston Suburbs',
'Boston/Cambridge',]:
            cities[c] = 'Boston'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Boston"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Boston"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Champaign Area',
'Champaign Urbana',]:
            cities[c] = 'Champaign'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Champaign"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Champaign"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Chicago Area',
'Chicago Metro',
'Chicago Suburbs',]:
            cities[c] = 'Chicago'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Chicago"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Chicago"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['District Of Columbia','Dc',
'Dc Area',
'Dc Metro Area',
'Dc Suburb',
'Washington Dc',
'Washington Dc Metro Area',
'Washington Dc Suburbs',
'Washington State',
'Washingtondc','Dmv Metro Area',]:
            cities[c] = "Washington DC"
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Washington DC"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Washington DC"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Philadelphia Area',
'Philadelphia Suburb',
'Philadelphia Suburbs',
'Philadelphiai',
'Philadephia',
'Philadlephia',
'Philedelphia',
'Philiadelpia',
'Phialdelphia',]:
            cities[c] = "Philadelphia"
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Philadelphia"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Philadelphia"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Portland Area',
'Portland Metro',
'Portland Metro Area',]:
            cities[c] = 'Portland'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Portland"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Portland"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Toronto On',
'Toronto Ontario',
'Toronto Ontario Canada',
'Tornto',]:
            cities[c] = 'Toronto'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Toronto"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Toronto"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Seattle Area',
'Seattle Metro',
'Seatle',
'Seatlle',]:
            cities[c] = 'Seattle'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Seattle"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Seattle"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Vancouver Area',
'Vancouver Bc',
'Vancouver Island',]:
            cities[c] = 'Vancouver'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Vancouver"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Vancouver"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
  
        if cities[c] in ['Calgary Ab',
'Calgary Alberta',
'Calgary Alberta Canada',]:
            cities[c] = 'Calgary'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])

        if cities[c] in [
'Dallas / Fort Worth',
'Dallas-Ft Worth',
'Dallas/Fort Worth',
'Dallas/Fort Worth Region',]:
            cities[c] = 'Dallas'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])

        if cities[c] in ['Denver Co',
'Denver Metro',
'Denver Metro Area',
'Denver-Metro',
'Denver/Boston',

]:
            cities[c] = 'Denver'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])

        if cities[c] in [
'Detroit Area',
'Detroit Metro',
'Detroit Metro Area',
]:
            cities[c] = 'Detroit'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])

        if cities[c] in [
'Houston Area',
'Houston Metro Area',
'Houston Texas',
]:
            cities[c] = 'Houston'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])

        if cities[c] in [
'Kansa City',
'Kansas Citt',
'Kansas City Area',
'Kansas City Region',
]:
            cities[c] = 'Kansas City'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in [
'Los Angeles Area',
'Los Angeles County',
'Los Angeles Metro',
'Los Angeles Metro Area',
'Los Angles',]:
            cities[c] = 'Los Angeles'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Minneapolis Metro',
'Minneapolis Suburbs',
'Minneapolis-St Paul',
'Minneapolis/St Paul',
'Minneapollis',
'Minnepolis',
'Minnesota',
'Minnespolis',
'Minneapilis',]:
            cities[c] = 'Minneapolis'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Milwaukee Area',
'Milwaukee Metro',
'Milwaukee Metro Area',]:
            cities[c] = 'Milwaukee'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in [



'Raleigh Durham',
'Raleigh Nc',
'Raleigh-Durham',

]:
            cities[c] = 'Raleigh'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in [
'New Yor',
'New York',
'New York Buty',
'New York City Suburbs',
'New York City/Brooklyn',
'New York City/Manhattan',
'New Yorkncity',
'Ny Metro',
'Ny Suburb',
'Nyack',
'Nyc',
'Nyc - Queens',
'Nyc Metro',
'Nyc Metro Area',]:
            cities[c] = 'New York City'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in ['Twin Cities Area',
'Twin Cities Metro',
'Twin Cities Metro Area',
'Twin Cities Suburbs',
]:
            cities[c] = 'Twin Cities'
            count = count+1
                        #             print("before:"+str(table_copy.iloc[c]["Lat"]))
#             print("before:"+str(table_copy.iloc[c]["Lng"]))
            newLat = table_copy[table_copy["City"]== "Calgary"]["Lat"]
            newLong =table_copy[table_copy["City"]== "Calgary"]["Lng"]
#             print("newLat: "+str(newLat.iloc[0]))
#             print("newLong: "+str(newLong.iloc[0]))
            table_copy.iloc[c]["Lat"] = newLat
            table_copy.iloc[c]["Lng"] = newLong
#             print(table_copy.iloc[c]["Lat"])
#             print(table_copy.iloc[c]["Lng"])
        if cities[c] in [
'California',
'Don’T Want To Answer',
'France',
'From Home',
'G','60K Small City',
'A City In The Uk',
'A Coruña',
'A Large City',
'A Major Canadian City',
'A Major One',
'A Small City',
'A Suburb Of Boston',
'A Very Large City',
'Affluent Chicago Suburb',
'Africa',
'Albany Region',
'Albuquerqur',
'All Of Them',
'All Over N Ca',
'Allen/Plano',
'Amsterdsm',
'Ann Arbor Area',
'Anon',
'Anonymous',
'Augusta IL',
'Atlanta/Decatur',
'Austin / New York',
'Austin Metro Area',
'Australia Not Sydney',
'Anchoragr',
'At Home',
'Barrie Ontario',
'Bay Area / Palo Alto',
'Bethesda Md',
'Birmingham Uk',
'Brea Ca',
'Bristol Uk',
'British Columbia',
'Burnaby Bc',
'Ca 100K Inhabitants',
'Cambridge Ma',
'Cambridge/Boston',
'Can\'T Say',
'Can\'T Share',
'Cartersville Ga',
'Choose Not To Answer',
'City',
'City In Middle Georgia',
'Company Is Based In Sf',
'Concord Home Based',
'Decline',
'Decline To Answer',
'Decline To Mention',
'Decline To Provide',
'Decline To State',
'Declined',
'Declined - Rural Area',
'Dont Want To Say',
'Don’T Want To Answer'
'G',
'Home',
'Home Based',
'Home Office',
'I Work From Home',
'Large Metro Area',
'Large Town/Small City',
'N/A',
'N/A - County',
'N/A - Work From Home',
'N/A Cloud-Based',
'Na',
'My House',
'No',
'No Answer',
'No City',
'None',
'Nope',
'Not A City',
'Not Answering',
'Not Applicable',
'Not Denver',
'Not Detroit',
'Not Disclosed',
'Not Disclosing',
'Not Provided',
'Not Saying',
'Not Sharing This',
'Rather Not Answer',
'Rather Not Say',
'Refuse To Answer',
'Small Canadian City',
'Small City',
'Small City In Sw Uk',
'Small Coastal Town',
'Small College Town',
'Small State - No Answer',
'Small Town',
'Small Town Ohio',
'This Is Too Identifying',
'Truth Or Consequences',
'Undisclosed',
'Usa',
'Varies',
'Variety',
'Various',
'Vancouver Area',
'Vancouver Bc',
'Vancouver Island',
'Virgina Beach',
'Virgnia Beach',
'Virtual',
'Virtual Role',
'Virtual Worker',
'Would Give Too Much Away',
'Would Rather Not Say',
'Work From Home',
'Xx',
'Xxx''Nan','Medium Size City',
'Mid-Size City',
'Midsized City',
'Nan',
'Rural Town',
'Rural Small Town',
'Rural/Suburban',
'Rural College Community',
'Rural College Town',
'Rural Area',
'Secret',
'See Above',
'Semirural City',
'Skip',
'To Much Detail',
'Too Identifiable',
'Too Small',
'Too Small To List',
'Xxx',]:
            cities[c] = ''
            count2= count2+1
    #print(commas)
   # print(np.unique(cities))
    table["City"] = cities
#     print(count)
#     print(count2)
    return table

# %%
def clean_location(tbl):
    x = standardize_countries(tbl)
    x = standardize_states(x)
    x = standardize_cities(x)

    return x



res = clean_location(table_copy)
for x in range(len(res["address"])):
    res["address"][x] = res["City"][x] + " " + res["State"][x]+ " " + res["Country"][x]
#     print(    res["address"][x])
for c in range(len(np.unique(res["City"]))):
    print("'"+np.unique(res["City"])[c]+"',")
res.to_csv("Re-CleanedData2021.csv")
# Out:
# <ipython-input-17-ae7c24322291>:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_copy.iloc[c]["Lat"] = newLat
# <ipython-input-17-ae7c24322291>:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_copy.iloc[c]["Lng"] = newLong
# <ipython-input-17-ae7c24322291>:472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_copy.iloc[c]["Lat"] = newLat
# ...
